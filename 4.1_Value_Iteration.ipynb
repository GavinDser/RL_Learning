# %%
from GridWorld_V1 import GridWorld_v1

# %%
grid = GridWorld_v1(fixed=["x.",".!"])
grid.show_map()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 grid = GridWorld_v1(fixed=["x.",".!"])
#       2 grid.show()
#
# TypeError: GridWorld_v1.__init__() got an unexpected keyword argument 'fixed'
